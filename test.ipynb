# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

from dotenv import load_dotenv
from media_sonju.vectordb.connect_db import connect_DB
from media_sonju.vectordb.pgvector import create_pgvector_store
from media_sonju.vectordb.set_model import set_embedding_model

load_dotenv()
db = connect_DB()
embeddings = set_embedding_model()
vectorstore = create_pgvector_store(db, embeddings)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 from dotenv import load_dotenv
# ----> 2 from media_sonju.vectordb.connect_db import connect_DB
#       3 from media_sonju.vectordb.pgvector import create_pgvector_store
#       4 from media_sonju.vectordb.set_model import set_embedding_model
#
# ModuleNotFoundError: No module named 'media_sonju'

# %%
from rag_workflow import create_self_rag_workflow
self_rag_app = create_self_rag_workflow(vectorstore)

print("Self-RAG 워크플로우 생성 완료!")
# Out:
# SelfRAGState 클래스 정의 완료!
# Self-RAG 워크플로우 생성 완료!

# %%
from IPython.display import Image, display

try:
    
    display(
        Image(
            self_rag_app.get_graph().draw_mermaid_png()
        )
    )
except Exception as e:
    print(f"그래프 표시 오류: {e}")
